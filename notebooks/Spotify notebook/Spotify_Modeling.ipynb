# %%
import pandas as pd


import seaborn as sns
import matplotlib.pyplot as plt

# models
from sklearn.svm import SVC
from lgbm
from sklearn.

# word vecotrizers
from sklearn.feature_extraction.text import TfidfVectorizer

import joblib

# %%
df = joblib.load(r"../../Data\preproccesed\Spotify_processed.pkl")

# %%
tf = TfidfVectorizer(stop_words= 'english', ngram_range=(2,4))

# %%
df.columns
# Out:
# Index(['Review', 'Rating', 'Sentiment'], dtype='object')

# %%
X = tf.fit_transform(df["Review"])
y = df['Sentiment']

# %% [markdown]
# # modeling
# ---

# %% [markdown]
# Best model: SVC_RBF with weighted F1 = 0.8654 <br>
# RandomForestClassifier: weighted F1 = 0.8477 <br>
# LGBMClassifier: weighted F1 = 0.8498 <br>
